# %%
import pandas as pd
import string
pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv("all_tweets_2.zip")
df=df.drop("Unnamed: 0",axis=1)
df.head()
# Out:
# C:\Users\Mikkel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,7,14,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0   user_id             user_name user_screen_name user_location  \
# 0           0  77986533  Greenpeace i Danmark     greenpeacedk     København
# 1           1  77986533  Greenpeace i Danmark     greenpeacedk     København
# 2           2  77986533  Greenpeace i Danmark     greenpeacedk     København
# 3           3  77986533  Greenpeace i Danmark     greenpeacedk     København
# 4           4  77986533  Greenpeace i Danmark     greenpeacedk     København
#
#                                     user_description  user_followers_count  \
# 0  Verdensomspændende miljøorganisation, i Danmar...                7712.0
# 1  Verdensomspændende miljøorganisation, i Danmar...                7712.0
# 2  Verdensomspændende miljøorganisation, i Danmar...                7712.0
# 3  Verdensomspændende miljøorganisation, i Danmar...                7712.0
# 4  Verdensomspændende miljøorganisation, i Danmar...                7712.0
#
#   user_friends_count  user_statuses_count                 user_created_at  \
# 0               5433               9889.0  Mon Sep 28 11:12:02 +0000 2009
# 1               5433               9889.0  Mon Sep 28 11:12:02 +0000 2009
# 2               5433               9889.0  Mon Sep 28 11:12:02 +0000 2009
# 3               5433               9889.0  Mon Sep 28 11:12:02 +0000 2009
# 4               5433               9889.0  Mon Sep 28 11:12:02 +0000 2009
#
#    ...      tweet_id  tweet_lang  \
# 0  ...  1.396131e+18          da
# 1  ...  1.396097e+18          da
# 2  ...  1.396094e+18          da
# 3  ...  1.396076e+18          da
# 4  ...  1.396063e+18          da
#
#                                      tweet_full_text tweet_retweeted  \
# 0  Mellem regnskyl nåede vi at fange et billede a...           False
# 1  “Hvert valg indtil 2050 bliver et klimavalg”, ...           False
# 2  Klimamarchen er kommet til Slotspladsen, og vo...           False
# 3  Tusinder på vej mod Christiansborg for at kræv...           False
# 4  Helt fantastisk at være mange demonstranter sa...           False
#
#   tweet_retweeted_status tweet_retweet_count  tweet_is_quote_status  \
# 0                    NaN                 3.0                  False
# 1                    NaN                 4.0                  False
# 2                    NaN                 3.0                  False
# 3                    NaN               100.0                  False
# 4                    NaN                 6.0                  False
#
#   tweet_quoted_status tweet_quote_count  \
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
#
#                                       tweet_entities
# 0  {'hashtags': [{'text': 'dkpol', 'indices': [20...
# 1  {'hashtags': [{'text': 'dkpol', 'indices': [17...
# 2  {'hashtags': [{'text': 'dkpol', 'indices': [16...
# 3  {'hashtags': [{'text': 'dkpol', 'indices': [10...
# 4  {'hashtags': [{'text': 'dkpol', 'indices': [13...
#
# [5 rows x 21 columns]

# %%
data=[df["user_screen_name"],df["tweet_full_text"]]
df_preproc=pd.concat(data, axis=1)

# %%
for i in df_preproc.tweet_full_text[5:10].to_list():
    w=re.sub(r"(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b", "", i)
    w=re.sub(r"@\w+", "", w)
    w=re.sub(r"[0-9]","", w)
    w=w.translate(str.maketrans("", "", string.punctuation))
    print(w.lower())
    print()
# Out:
# tiden er ved at indhente  og deres grønne klimaløfter fra folketingsvalget
#
# vores aktivister har her til morgen malet et budskab til regeringen som opvarmning til klimamarch kl  i dag for genforhandlinger af efterårets skuffende aftaler endnuettabtår dkmedier
#
# episoden kan desuden bruges som indledning til klimamarchen i københavn i morgen kl  del invitér og tryk deltag  herinde
#
# på vej hjem til weekend anbefaler vi en tur kloden rundt med  og  i nyeste episode af podcasten greenpeace udvider klimaboblen få status på internationale klimaløfter og om der stadig er grund til panik kan findes på din vante podcastkanal dkgreen
#
# rt  ingen grund til at have en tom klimakalender i næste ugeallerede i morgen går det løs
#  …
#
# endnu et folketingsår er ved at gå på hæld  har vejet s klimapolitiske aftaler og fundet dem for let derfor tager de nu nye metoder i brug for at sikre sig klimapolitik der leverer på målene for parisaftalen og klimaloven dkpol dkgreen
